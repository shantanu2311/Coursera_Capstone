# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner

# !pip install geopy 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# Out:
# Requirement already satisfied: geopy in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from geopy) (1.50)

# %%
import urllib.request
url = "https://finkode.com/hr/gurgaon.html"
page = urllib.request.urlopen(url)

from bs4 import BeautifulSoup 
soup = BeautifulSoup(page, "html5lib")

# %%
tables=soup.find_all("table") 

for table in tables:
    head = table.find_all('caption')
    headings = [h2.text.strip() for h2 in head]
    if headings == ['List of Post Offices/ Pincodes in areas under Gurgaon district, Haryana']:
        break
#table

# %%
A=[]
B=[]

for row in table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==2:
        A.append(cells[0].findAll(text=True))
        B.append(cells[1].findAll(text=True))

df=pd.DataFrame(A,columns=['Area'])
df['Pincode']=B
df.head()
# Out:
#                  Area   Pincode
# 0                Agon  [122104]
# 1           Air Force  [122105]
# 2   Alkatel India Ltd  [122225]
# 3  American Institute  [122210]
# 4       AO, BSNL GMTD  [122234]

# %%
df['Pincode'] = df['Pincode'].str[0]
df
# Out:
#                            Area Pincode
# 0                          Agon  122104
# 1                     Air Force  122105
# 2             Alkatel India Ltd  122225
# 3            American Institute  122210
# 4                 AO, BSNL GMTD  122234
# ..                          ...     ...
# 185                Urban Estate  122001
# 186        USAPL Dundahera Ph-5  122218
# 187                     Wazipur  123505
# 188                   Wazirabad  122003
# 189  Wipro India Ltd, Dundahere  122214
#
# [190 rows x 2 columns]

# %%
#df['Pincode'] = df['Pincode'].astype(str)+',India'
df.head()
# Out:
#                  Area Pincode
# 0                Agon  122104
# 1           Air Force  122105
# 2   Alkatel India Ltd  122225
# 3  American Institute  122210
# 4       AO, BSNL GMTD  122234

# %%
# !pip install pgeocode
# Out:
# Requirement already satisfied: pgeocode in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (0.2.1)
# Requirement already satisfied: requests in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from pgeocode) (2.22.0)
# Requirement already satisfied: numpy in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from pgeocode) (1.18.1)
# Requirement already satisfied: pandas in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from pgeocode) (1.0.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from requests->pgeocode) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from requests->pgeocode) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from requests->pgeocode) (2019.11.28)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from pandas->pgeocode) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from pandas->pgeocode) (2019.3)
# Requirement already satisfied: six>=1.5 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas->pgeocode) (1.14.0)

# %%
import pgeocode
lis  = df.loc[:,"Pincode"]
lis2 = lis.tolist()
nominatim = pgeocode.Nominatim('IN') #Country code

# %%
df2 = nominatim.query_postal_code(lis2)
df2
# Out:
#     postal_code country code  \
# 0        122104           IN
# 1        122105           IN
# 2        122225          NaN
# 3        122210          NaN
# 4        122234          NaN
# ..          ...          ...
# 185      122001           IN
# 186      122218          NaN
# 187      123505          NaN
# 188      122003           IN
# 189      122214          NaN
#
#                                             place_name state_name  state_code  \
# 0    Ferozepur Jhirka, Doha, Rawli, Agon, Hirwari, ...    Haryana        10.0
# 1    Rathiwas, Jhamuwas, Baghanki, Mohamadpur Ahir,...    Haryana        10.0
# 2                                                  NaN        NaN         NaN
# 3                                                  NaN        NaN         NaN
# 4                                                  NaN        NaN         NaN
# ..                                                 ...        ...         ...
# 185  Basai Road, Gurgaon Sector 17, Urban Estate (G...    Haryana        10.0
# 186                                                NaN        NaN         NaN
# 187                                                NaN        NaN         NaN
# 188  Smaspur, Jharsa, Wazirabad, Gwal Pahari, Gurga...    Haryana        10.0
# 189                                                NaN        NaN         NaN
#
#     county_name  county_code    community_name  community_code  latitude  \
# 0       Gurgaon         86.0  Ferozepur Jhirka             NaN   28.3681
# 1       Gurgaon         86.0             Tauru             NaN   28.2620
# 2           NaN          NaN               NaN             NaN       NaN
# 3           NaN          NaN               NaN             NaN       NaN
# 4           NaN          NaN               NaN             NaN       NaN
# ..          ...          ...               ...             ...       ...
# 185     Gurgaon         86.0        Basai Road             NaN   28.4180
# 186         NaN          NaN               NaN             NaN       NaN
# 187         NaN          NaN               NaN             NaN       NaN
# 188     Gurgaon         86.0        Sector -45             NaN   28.4180
# 189         NaN          NaN               NaN             NaN       NaN
#
#      longitude  accuracy
# 0    76.948750       4.0
# 1    76.923164       4.0
# 2          NaN       NaN
# 3          NaN       NaN
# 4          NaN       NaN
# ..         ...       ...
# 185  76.983900       1.0
# 186        NaN       NaN
# 187        NaN       NaN
# 188  76.983900       1.0
# 189        NaN       NaN
#
# [190 rows x 12 columns]

# %%
df2.rename(columns = {'postal_code':'Pincode'},inplace=True)
df3= pd.merge(df,df2,on ='Pincode', how ='inner')
df3.head()
# Out:
#    Area Pincode country code  \
# 0  Agon  122104           IN
# 1  Agon  122104           IN
# 2  Agon  122104           IN
# 3  Agon  122104           IN
# 4  Agon  122104           IN
#
#                                           place_name state_name  state_code  \
# 0  Ferozepur Jhirka, Doha, Rawli, Agon, Hirwari, ...    Haryana        10.0
# 1  Ferozepur Jhirka, Doha, Rawli, Agon, Hirwari, ...    Haryana        10.0
# 2  Ferozepur Jhirka, Doha, Rawli, Agon, Hirwari, ...    Haryana        10.0
# 3  Ferozepur Jhirka, Doha, Rawli, Agon, Hirwari, ...    Haryana        10.0
# 4  Ferozepur Jhirka, Doha, Rawli, Agon, Hirwari, ...    Haryana        10.0
#
#   county_name  county_code    community_name  community_code  latitude  \
# 0     Gurgaon         86.0  Ferozepur Jhirka             NaN   28.3681
# 1     Gurgaon         86.0  Ferozepur Jhirka             NaN   28.3681
# 2     Gurgaon         86.0  Ferozepur Jhirka             NaN   28.3681
# 3     Gurgaon         86.0  Ferozepur Jhirka             NaN   28.3681
# 4     Gurgaon         86.0  Ferozepur Jhirka             NaN   28.3681
#
#    longitude  accuracy
# 0   76.94875       4.0
# 1   76.94875       4.0
# 2   76.94875       4.0
# 3   76.94875       4.0
# 4   76.94875       4.0

# %%
df4 = df3.filter(['Area','Pincode','community_name','latitude','longitude'], axis=1)
df4.head()
# Out:
#    Area Pincode    community_name  latitude  longitude
# 0  Agon  122104  Ferozepur Jhirka   28.3681   76.94875
# 1  Agon  122104  Ferozepur Jhirka   28.3681   76.94875
# 2  Agon  122104  Ferozepur Jhirka   28.3681   76.94875
# 3  Agon  122104  Ferozepur Jhirka   28.3681   76.94875
# 4  Agon  122104  Ferozepur Jhirka   28.3681   76.94875

# %%
df5= df4.drop_duplicates(subset='Area', keep='first')
df4
# Out:
#                             Area Pincode    community_name  latitude  \
# 0                           Agon  122104  Ferozepur Jhirka   28.3681
# 1                           Agon  122104  Ferozepur Jhirka   28.3681
# 2                           Agon  122104  Ferozepur Jhirka   28.3681
# 3                           Agon  122104  Ferozepur Jhirka   28.3681
# 4                           Agon  122104  Ferozepur Jhirka   28.3681
# ...                          ...     ...               ...       ...
# 1297      SMS Limited, Dundahera  122216               NaN       NaN
# 1298               South City-II  122018               NaN   28.4001
# 1299    Spice jet Ltd, Sector-18  122202               NaN       NaN
# 1300        USAPL Dundahera Ph-5  122218               NaN       NaN
# 1301  Wipro India Ltd, Dundahere  122214               NaN       NaN
#
#       longitude
# 0      76.94875
# 1      76.94875
# 2      76.94875
# 3      76.94875
# 4      76.94875
# ...         ...
# 1297        NaN
# 1298   76.96610
# 1299        NaN
# 1300        NaN
# 1301        NaN
#
# [1302 rows x 5 columns]

# %%
df5=df5.dropna()
df5 = df5.reset_index(drop=True)
df5
# Out:
#                 Area Pincode    community_name  latitude  longitude
# 0               Agon  122104  Ferozepur Jhirka   28.3681  76.948750
# 1              Bewan  122104  Ferozepur Jhirka   28.3681  76.948750
# 2               Doha  122104  Ferozepur Jhirka   28.3681  76.948750
# 3   Ferozepur Jhirka  122104  Ferozepur Jhirka   28.3681  76.948750
# 4            Hirwari  122104  Ferozepur Jhirka   28.3681  76.948750
# ..               ...     ...               ...       ...        ...
# 84       Narsinghpur  122004       Narsinghpur   28.4032  76.983633
# 85       Sikanderpur  122004       Narsinghpur   28.4032  76.983633
# 86          Sikohpur  122004       Narsinghpur   28.4032  76.983633
# 87        Palam Road  122015        Palam Road   28.4001  76.966100
# 88           Sarhaul  122015        Palam Road   28.4001  76.966100
#
# [89 rows x 5 columns]

# %%
df6=df5.sort_values("Pincode")
df6 = df6.reset_index(drop=True)
df6.head(89)
# Out:
#              Area Pincode community_name  latitude  longitude
# 0    South City-I  122001     Basai Road   28.4180  76.983900
# 1   Shivaji Nagar  122001     Basai Road   28.4180  76.983900
# 2       Sector-17  122001     Basai Road   28.4180  76.983900
# 3      New Colony  122001     Basai Road   28.4180  76.983900
# 4     Mini Sectt.  122001     Basai Road   28.4180  76.983900
# ..            ...     ...            ...       ...        ...
# 84       Moolthan  122108         Nagina   28.3681  76.973629
# 85         Nagina  122108         Nagina   28.3681  76.973629
# 86         Sakras  122108         Nagina   28.3681  76.973629
# 87           Umra  122108         Nagina   28.3681  76.973629
# 88       Budarpur  122108         Nagina   28.3681  76.973629
#
# [89 rows x 5 columns]

# %%
df7=df6.iloc[5:35,]
df7
# Out:
#                  Area Pincode     community_name  latitude  longitude
# 5        Gurgaon Kty.  122001         Basai Road   28.4180  76.983900
# 6             Gurgaon  122001         Basai Road   28.4180  76.983900
# 7          Basai Road  122001         Basai Road   28.4180  76.983900
# 8         Arjun Nagar  122001         Basai Road   28.4180  76.983900
# 9        Urban Estate  122001         Basai Road   28.4180  76.983900
# 10         Sohna Adda  122001         Basai Road   28.4180  76.983900
# 11           Nathupur  122002             Dlf Qe   28.4180  76.983900
# 12             DLF QE  122002             Dlf Qe   28.4180  76.983900
# 13         Chakkarpur  122002             Dlf Qe   28.4180  76.983900
# 14            Smaspur  122003         Sector -45   28.4180  76.983900
# 15             Jharsa  122003         Sector -45   28.4180  76.983900
# 16        Gwal Pahari  122003         Sector -45   28.4180  76.983900
# 17          Wazirabad  122003         Sector -45   28.4180  76.983900
# 18         Sector -45  122003         Sector -45   28.4180  76.983900
# 19            Khandsa  122004        Narsinghpur   28.4032  76.983633
# 20       Kherki Daula  122004        Narsinghpur   28.4032  76.983633
# 21          Lakhnaula  122004        Narsinghpur   28.4032  76.983633
# 22        Narsinghpur  122004        Narsinghpur   28.4032  76.983633
# 23        Sikanderpur  122004        Narsinghpur   28.4032  76.983633
# 24           Sikohpur  122004        Narsinghpur   28.4032  76.983633
# 25      Railwary Road  122006       Railway Road   28.4592  76.985000
# 26    Gurgaon Village  122006       Railway Road   28.4592  76.985000
# 27              Basai  122006       Railway Road   28.4592  76.985000
# 28          Daultabad  122006       Railway Road   28.4592  76.985000
# 29  Industrial Estate  122007  Industrial Estate   28.4180  76.983900
# 30          DLF Ph-II  122008          Dlf Ph-ii   28.4180  76.983900
# 31    Galleria DLF-IV  122009    Galleria Dlf-iv   28.4180  76.983900
# 32         DLF Ph-III  122010         Dlf Ph-iii   28.4001  76.966100
# 33         Palam Road  122015         Palam Road   28.4001  76.966100
# 34            Sarhaul  122015         Palam Road   28.4001  76.966100

# %%
CLIENT_ID = 'SVXBQLDXOARVTQR2OG3JQFHBQK3PAVHOTN4TBLLMT1TC1HIG' # your Foursquare ID
CLIENT_SECRET = 'PCK52X4UC0TBKAAVPITUDTWPCCTVPB0INCUWS2HQA2RA1UM0' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

LIMIT = 15 # limit of number of venues returned by Foursquare API
radius = 3000 #3Km radius

# %%
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
search_query_list = ['Clinic','Hospital']
print(type(search_query_list))
venues_count=[]
lat=[]
long=[]
LIMIT = 300
for ind in df6.index:
    latitude = df6['latitude'][ind]
    longitude = df6['longitude'][ind]
    for ind2 in search_query_list:
        search_query=ind2
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
        results = requests.get(url).json()
        venues = results['response']['venues']
        dataframe = json_normalize(venues)
        val_count = len(dataframe.index)
            venues_count.append(val_count)
        lat.append(latitude)
        long.append(longitude)
# Out:
# <class 'list'>
# C:\Users\shantanu.srivastava\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
num_count = np.array(venues_count)
headings_queries = search_query_list
reshaped_output = num_count.reshape(len(df6),len(headings_queries))

#print(reshaped)
foursquare_output = pd.DataFrame(reshaped_output, columns=headings_queries)
#lat
#foursquare_output['latitude']=lat
#foursquare_output['longitude']=long
df_dum=foursquare_output

# %%
print(type(foursquare_output))
print(foursquare_output.shape)
df6.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (89, 4)
#             Area Pincode community_name  latitude  longitude
# 0   South City-I  122001     Basai Road    28.418    76.9839
# 1  Shivaji Nagar  122001     Basai Road    28.418    76.9839
# 2      Sector-17  122001     Basai Road    28.418    76.9839
# 3     New Colony  122001     Basai Road    28.418    76.9839
# 4    Mini Sectt.  122001     Basai Road    28.418    76.9839

# %%
num_count1 = np.array(lat)
reshaped_output1 = num_count1.reshape(len(df6),len(headings_queries))
#reshaped_output1 
num_count2 = np.array(long)
reshaped_output2 = num_count2.reshape(len(df6),len(headings_queries))
#reshaped_output2

# %%
foursquare_output1 = pd.DataFrame(reshaped_output1)
foursquare_output2 = pd.DataFrame(reshaped_output2)
#foursquare_output['latitude'] = reshaped_output1.tolist()
#foursquare_output['longitude'] = reshaped_output2.tolist()

# %%
#foursquare_output=pd.concat([foursquare_output,foursquare_output1,foursquare_output2],axis=1) 
#foursquare_output=foursquare_output.drop(foursquare_output.iloc[:,3:4], axis=1)
name_list = ['Clinic','Hospital','latitude','longitude']
foursquare_output.columns= name_list
foursquare_output.head()
# Out:
#    Clinic  Hospital  latitude  longitude
# 0       2         1    28.418    76.9839
# 1       2         1    28.418    76.9839
# 2       2         1    28.418    76.9839
# 3       2         1    28.418    76.9839
# 4       2         1    28.418    76.9839

# %%
df7=pd.merge(foursquare_output,df6,on ='latitude', how ='inner')
df7.shape
# Out:
# (1261, 8)

# %%
#df7.groupby('community_name').count()
df8=df7.drop_duplicates(subset='community_name', keep='first')
#df8.rename(columns={'longitude_y':'longitude'},inplace=True)
df8.head()
# Out:
#     Clinic  Hospital  latitude  longitude_x               Area Pincode  \
# 0        2         1    28.418      76.9839       South City-I  122001
# 11       2         1    28.418      76.9839           Nathupur  122002
# 14       2         1    28.418      76.9839            Smaspur  122003
# 19       2         1    28.418      76.9839  Industrial Estate  122007
# 20       2         1    28.418      76.9839          DLF Ph-II  122008
#
#        community_name  longitude
# 0          Basai Road    76.9839
# 11             Dlf Qe    76.9839
# 14         Sector -45    76.9839
# 19  Industrial Estate    76.9839
# 20          Dlf Ph-ii    76.9839

# %%
df8 = df8.reset_index(drop=True)
df8.shape
df9=df8.drop(["longitude_x"],axis=1)
df9.head()
# Out:
#    Clinic  Hospital  latitude               Area Pincode     community_name  \
# 0       2         1    28.418       South City-I  122001         Basai Road
# 1       2         1    28.418           Nathupur  122002             Dlf Qe
# 2       2         1    28.418            Smaspur  122003         Sector -45
# 3       2         1    28.418  Industrial Estate  122007  Industrial Estate
# 4       2         1    28.418          DLF Ph-II  122008          Dlf Ph-ii
#
#    longitude
# 0    76.9839
# 1    76.9839
# 2    76.9839
# 3    76.9839
# 4    76.9839

# %%
df9=df9[['community_name','Pincode','Area','Clinic', 'Hospital','latitude','longitude']]
df9=df9.reset_index(drop=True)
df10=df9

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !pip install folium
import folium # map rendering library

address = 'Gurugram'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
#print('The geograpical coordinate of Gurgaon are {}, {}.'.format(latitude, longitude))

# create map of Gurgaon using latitude and longitude values
map_Gurgaon = folium.Map(location=[latitude, longitude], zoom_start=14)

map_Gurgaon
# Out:
# Requirement already satisfied: folium in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from folium) (1.18.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from folium) (2.11.1)
# Requirement already satisfied: requests in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: branca>=0.3.0 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from folium) (0.4.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\shantanu.srivastava\anaconda3\lib\site-packages (from requests->folium) (1.25.8)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# add markers to map
for lat, lng, community in zip(df9['latitude'], df9['longitude'], df9['community_name']):
    label = '{}'.format(community)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Gurgaon)  
    
map_Gurgaon
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df9.head()
# Out:
#      community_name Pincode              Area  Clinic  Hospital  latitude  \
# 0             Sohna  122103          Bhirauti       0         0   28.2474
# 1             Tauru  122105           Dulawat       0         0   28.2620
# 2  Nsg Camp Manesar  122051  Nsg Camp Manesar       0         2   28.3574
# 3            Nagina  122108            Bhadas       0         2   28.3681
# 4  Ferozepur Jhirka  122104             Bewan       0         2   28.3681
#
#    longitude
# 0  77.056267
# 1  76.923164
# 2  76.921500
# 3  76.973629
# 4  76.948750

# %%
# set number of clusters
kclusters =4
df10=df9[['Clinic','Hospital']]
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df10)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([3, 3, 1, 1, 1, 1, 3, 3, 3, 3, 3, 3, 0, 0, 0, 0, 0, 0, 2])

# %%
# add clustering labels
df10.insert(0, 'Cluster Labels', kmeans.labels_)
df10.head()
# Out:
#    Cluster Labels  Clinic  Hospital
# 0               3       0         0
# 1               3       0         0
# 2               1       0         2
# 3               1       0         2
# 4               1       0         2

# %%
#df10=df10.merge(df9, how='outer')
#df11=df10.drop_duplicates(subset='community_name', keep='first')
df11.sort_values(by=['Cluster Labels'], inplace=True)
df11=df11.reset_index(drop=True)
df11
# Out:
#     Cluster Labels  Clinic  Hospital                community_name Pincode  \
# 0                0       2         1                        Dlf Qe  122002
# 1                0       2         1                    Sector -45  122003
# 2                0       2         1             Industrial Estate  122007
# 3                0       2         1                     Dlf Ph-ii  122008
# 4                0       2         1                    Basai Road  122001
# 5                0       2         1               Galleria Dlf-iv  122009
# 6                1       0         2              Ferozepur Jhirka  122104
# 7                1       0         2                       Bhondsi  122102
# 8                1       0         2              Nsg Camp Manesar  122051
# 9                1       0         2                        Nagina  122108
# 10               2       6         4                  Railway Road  122006
# 11               3       1         0  Industrial Complex Dundahera  122016
# 12               3       1         0                   Palam Vihar  122017
# 13               3       0         0                    Badshahpur  122101
# 14               3       0         0                         Tauru  122105
# 15               3       1         0                   Narsinghpur  122004
# 16               3       0         0                         Sohna  122103
# 17               3       1         0                    Dlf Ph-iii  122010
# 18               3       1         0                    Palam Road  122015
#
#                             Area  latitude  longitude
# 0                       Nathupur   28.4180  76.983900
# 1                        Smaspur   28.4180  76.983900
# 2              Industrial Estate   28.4180  76.983900
# 3                      DLF Ph-II   28.4180  76.983900
# 4                   South City-I   28.4180  76.983900
# 5                Galleria DLF-IV   28.4180  76.983900
# 6                          Bewan   28.3681  76.948750
# 7                         Rithoj   28.3681  76.927086
# 8               Nsg Camp Manesar   28.3574  76.921500
# 9                         Bhadas   28.3681  76.973629
# 10                 Railwary Road   28.4592  76.985000
# 11  Industrial Complex Dundahera   28.4001  76.966100
# 12                    Carterpuri   28.4001  76.966100
# 13                        Teekli   28.3932  76.884400
# 14                       Dulawat   28.2620  76.923164
# 15                       Khandsa   28.4032  76.983633
# 16                      Bhirauti   28.2474  77.056267
# 17                    DLF Ph-III   28.4001  76.966100
# 18                    Palam Road   28.4001  76.966100

# %%
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df11['latitude'], df11['longitude'], df11['Area'], df11['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_Gurgaon)
       
map_Gurgaon
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
